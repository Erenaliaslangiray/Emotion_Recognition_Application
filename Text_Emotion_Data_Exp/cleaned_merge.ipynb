# %%
#Author: Eren Ali Aslangiray

import pandas as pd

# %%
df2 = pd.read_csv("/Users/erenmac/Desktop/NEW_DATA/Cleaned_Data/DF2.csv")
df4 = pd.read_json("/Users/erenmac/Desktop/NEW_DATA/Cleaned_Data/DF4.json")
df8 = pd.read_csv("/Users/erenmac/Desktop/NEW_DATA/Cleaned_Data/DF8.csv")
df11 = pd.read_csv("/Users/erenmac/Desktop/NEW_DATA/Cleaned_Data/DF11.csv")
df13 = pd.read_csv("/Users/erenmac/Desktop/NEW_DATA/Cleaned_Data/DF13.csv")
df17 = pd.read_csv("/Users/erenmac/Desktop/NEW_DATA/Cleaned_Data/DF17.csv")

# %%
df2.emotion.unique()
# Out:
# array(['neutral', 'anger', 'happy', 'disgust', 'sad', 'surprise', 'fear'],
#       dtype=object)

# %%
df4[1].unique()
# Out:
# array(['sad', 'fear', 'happy', 'anger', 'surprise'], dtype=object)

# %%
df8["2"].unique()
# Out:
# array(['sad', 'happy'], dtype=object)

# %%
df13.emotions.unique()
# Out:
# array(['sad', 'happy', 'anger', 'fear', 'surprise'], dtype=object)

# %% [markdown]
# # Negative analysis data

# %%
df17.annotation.unique()
# Out:
# array(['negative'], dtype=object)

# %%
reverse_dict = {"sadness":"sad", "joy":"happy","love":"happy","fear":"fear","anger":"anger","thankfulness":"happy","surprise":"surprise"}

# %%
df4[1] = df4[1].map(reverse_dict)

# %%
df8 = df8.drop(columns = ["Unnamed: 0","2","3"])

# %%
df8[0] = df8["2"]
df8[1] = df8["3"]

# %%
df8
# Out:
#           0                                                  1
# 0       sad  @PressSec sounds so defensive  &amp; combative...
# 1     happy  #Cheers &amp; #Happy #InternationalWomensDay f...
# 2     happy  #happy #wednesday #evening with #fashion #eleg...
# 3     happy  Bye bye #newyork ❤️😎 Thanks for everything 😃#t...
# 4     happy  Never a dull night in #dc - #happy #instagood ...
# 5     happy  Natural lighting 💁🏻\n•\n•\n•\n#internationalwo...
# 6     happy  Sretan 8mi Mart\nHappy International Women's D...
# 7       sad  "Roller Luggage: How Does It Work." Now playin...
# 8     happy  The Sun is Shinning On Me 😎🙌🏻🙏🏻🌞 #happy #love ...
# 9       sad  First @realDonaldTrump Falsely claims @POTUS44...
# 10    happy  #IAmAWoman what's your #Superpower? #👑 #Happy ...
# 11    happy  Happy Humpday! #happy #humpday #atl #nyc #la #...
# 12      sad  “Anything with the word ‘care’ in it pretty mu...
# 13    happy  FINAFREAKINGLLY got the #whip cleaned after AL...
# ...

# %%
df17 = df17.drop(columns = ["Unnamed: 0"])

# %%
df2[1] = df2.sentence

# %%
df8 = df8.drop(columns = ["2","3"])

# %%
df13[1] = df13.text

# %%
df13[0] = df13.emotions

# %%
frames = [df2,df4,df13,df8,df11]
result = pd.concat(frames)

# %%
result = result.reset_index(drop = True)

# %%
result.to_json("final_multilabel.json")

# %%
df11 = df11.drop(columns = ["0"])

# %%
df11[1] = df11["3"]

# %%
a = a.dropna()

# %%
a = df11

# %%
df11 = a

# %%
df11[0] = df11["0"]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df11
# Out:
#                                                      1         0
# 0    He who exalts himself shall be humbled; and he...     happy
# 1    I have sought the truth of my soul and found i...     happy
# 2    God is utterly powerless without Human interve...     happy
# 3    This world needs a tight group hug Tight enoug...     happy
# 4    A Godly husband - knows you - trusts you - lov...     happy
# 5                             I'll be your huckleberry   neutral
# 6    BIBLE = Big Irrelevant Book of Lies and Exagge...     anger
# 7    Happy Independence Day to America and her beau...     happy
# 8    Let my house be built by wisdom and become str...   neutral
# 9    ILoveIslamBecause and v should love Islam beca...     happy
# 10   God > My fears God > My insecurities God > My ...     happy
# 11   I am Baloch and I will not allow Talibanizatio...     anger
# 12   He became a slave to the cross that men could ...     happy
# ...

# %%
result
# Out:
#                0                                                  1
# 0        neutral  How much of the forecast was genuine and how m...
# 1        neutral  I did touch them one time you see but of cours...
# 2        neutral  We find that choice theorists admit that they ...
# 3        neutral                Well here I am with an olive branch
# 4        neutral  Its rudder and fin were both knocked out and a...
# 5          anger            Over my dead body are you arresting him
# 6        neutral   Don't let him pick a fight now we're almost home
# 7        neutral  He's a good fighter but there are certain poin...
# 8          happy  Aggie finally found the cat a good home and fr...
# 9        neutral  She left the citizens of Riverbank to their sh...
# 10         happy                     You must sink your differences
# 11       disgust      Brian as ever decided not to sit on the fence
# 12       neutral  This is turning into one of those mediaeval di...
# ...
