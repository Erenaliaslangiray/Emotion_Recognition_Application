# %%
#Author: Eren Ali Aslangiray

import librosa
import matplotlib.pyplot as plt
import librosa.display
from jupyterthemes import jtplot
jtplot.style(context='talk', fscale=1.4, spines=False)
import numpy as np
import scipy

# %%
print ("Result For Anger Sentence")
wave,sr = librosa.load("anger.wav",mono=True)
plt.figure(figsize=(12,4))
plt.axis()
librosa.display.waveplot(wave,sr=sr)

mfccs = librosa.feature.mfcc(y=wave,sr=sr,n_mfcc=40)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfccs,x_axis ="time")
plt.colorbar()

mfcc_delta = librosa.feature.delta(mfccs)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc_delta,x_axis ="time")
plt.colorbar()

mfcc_dct = scipy.fftpack.dct(mfccs)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc_dct,x_axis ="time")
plt.colorbar()

rms = librosa.feature.rmse(y=wave)
S = librosa.feature.melspectrogram(y=wave, sr=sr)
plt.figure(figsize=(12,8))
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='RMS Energy')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max),y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()
# Out:
# Result For Anger Sentence

# %%
plt.figure(figsize=(12,6))
plt.plot(np.mean(librosa.feature.mfcc(y=wave, sr=sr, n_mfcc=40).T,axis=0))

# %%
plt.figure(figsize=(12,6))
plt.plot(np.mean(mfcc_dct.T,axis = 0))

# %%
len(np.mean(mfcc_dct.T,axis = 0))
# Out:
# 40

# %%
plt.plot(librosa.feature.rmse(y=wave).T)

# %%
np.mean(librosa.feature.rmse(y=wave))
# Out:
# 0.0042647785

# %%
np.mean(librosa.feature.rmse(y=wave))
# Out:
# 0.008677954

# %%
np.mean(librosa.feature.rmse(y=wave))
# Out:
# 0.002151557

# %%
plt.plot(np.mean(librosa.amplitude_to_db(S, ref=np.max),axis=0))

# %%
plt.plot(np.mean(librosa.amplitude_to_db(S, ref=np.max).T,axis=0))

# %%
print ("Result For Happy Sentence")

wave,sr = librosa.load("happy.wav",mono=True)
plt.figure(figsize=(12,4))
plt.axis()
librosa.display.waveplot(wave,sr=sr)

S = librosa.feature.melspectrogram(y=wave, sr=sr)
mfccs = librosa.feature.mfcc(y=wave,sr=sr,n_mfcc=20)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfccs,x_axis ="time")
plt.colorbar()

mfcc_delta = librosa.feature.delta(mfccs)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc_delta,x_axis ="time")
plt.colorbar()

mfcc_dct = scipy.fftpack.dct(mfccs)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc_dct,x_axis ="time")
plt.colorbar()

rms = librosa.feature.rmse(y=wave)
plt.figure(figsize=(12,8))
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='RMS Energy')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max),y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()
# Out:
# Result For Happy Sentence

# %%
print ("Result For Sad Sentence")

wave,sr = librosa.load("sad.wav",mono=True)
plt.figure(figsize=(12,4))
plt.axis()
librosa.display.waveplot(wave,sr=sr)

S = librosa.feature.melspectrogram(y=wave, sr=sr)
mfccs = librosa.feature.mfcc(y=wave,sr=sr,n_mfcc=20)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfccs,x_axis ="time")
plt.colorbar()

mfcc_delta = librosa.feature.delta(mfccs)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc_delta,x_axis ="time")
plt.colorbar()

mfcc_dct = scipy.fftpack.dct(mfccs)
plt.figure(figsize=(12,4))
librosa.display.specshow(mfcc_dct,x_axis ="time")
plt.colorbar()

rms = librosa.feature.rmse(y=wave)
plt.figure(figsize=(12,8))
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='RMS Energy')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max),y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()
# Out:
# Result For Sad Sentence

# %%
import pywt

# %%
a,b = pywt.dwt(wave, 'db1')

# %%
plt.figure(figsize=(12,4))
plt.plot(a)
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.plot(b)
plt.show()

# %%
mfcc123 = np.mean(librosa.feature.mfcc(y=wave, sr=sr, n_mfcc=20).T,axis=0)

# %%
plt.figure(figsize=(12,4))
plt.plot(np.mean(mfccs.T,axis=1))

# %%
plt.figure(figsize=(12,4))
plt.plot(mfcc123)

# %%
mfccs.T.shape
# Out:
# (20, 166)
